# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

url = 'https://api.github.com/events'
r = requests.get(url)
print(r.text)
# Out:
# [{"id":"12705603148","type":"PushEvent","actor":{"id":16037265,"login":"tool3","display_login":"tool3","gravatar_id":"","url":"https://api.github.com/users/tool3","avatar_url":"https://avatars.githubusercontent.com/u/16037265?"},"repo":{"id":274314092,"name":"tool3/lsi","url":"https://api.github.com/repos/tool3/lsi"},"payload":{"push_id":5269196345,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"9a4105a2eb9d7ff1b852bbb121de6749e36fd214","before":"dca3b3ce83372086bd091ff8c5060f444b8c1e73","commits":[{"sha":"9a4105a2eb9d7ff1b852bbb121de6749e36fd214","author":{"email":"talhayut.dev@gmail.com","name":"Tal Hayut"},"message":"Create LICENSE","distinct":true,"url":"https://api.github.com/repos/tool3/lsi/commits/9a4105a2eb9d7ff1b852bbb121de6749e36fd214"}]},"public":true,"created_at":"2020-06-23T05:09:30Z"},{"id":"12705603155","type":"WatchEvent","actor":{"id":12604378,"login":"t13ka","display_login":"t13ka","gravatar_id":"","url":"https://api.github.com/users/t13ka","avatar_url":"https://avatars.githubusercontent.com/u/12604378?"},"repo":{"id":501687,"name":"antlr/antlr4","url":"https://api.github.com/repos/antlr/antlr4"},"payload":{"action":"started"},"public":true,"created_at":"2020-06-23T05:09:30Z","org":{"id":80584,"login":"antlr","gravatar_id":"","url":"https://api.github.com/orgs/antlr","avatar_url":"https://avatars.githubusercontent.com/u/80584?"}},{"id":"12705603151","type":"PushEvent","actor":{"id":43103463,"login":"stringtheory1234","display_login":"stringtheory1234","gravatar_id":"","url":"https://api.github.com/users/stringtheory1234","avatar_url":"https://avatars.githubusercontent.com/u/43103463?"},"repo":{"id":269122626,"name":"googleinterns/gpay-virtual-queue","url":"https://api.github.com/repos/googleinterns/gpay-virtual-queue"},"payload":{"push_id":5269196343,"size":5,"distinct_size":1,"ref":"refs/heads/master","head":"a6d4414810fa478562de178ebcdd7745bcd987a5","before":"7348e80d159953f4f9dc7d980325070545044111","commits":[{"sha":"d0d253c56fb44b6d0da31f125fc900a8bca9b9cf","author":{"email":"ikoder@google.com","name":"ikoder"},"message":"Add Specific Shop for Shop Owner feature","distinct":false,"url":"https://api.github.com/repos/googleinterns/gpay-virtual-queue/commits/d0d253c56fb44b6d0da31f125fc900a8bca9b9cf"},{"sha":"5344b686f26ec56ec7cdc142f81c5a48da4fa660","author":{"email":"ikoder@google.com","name":"ikoder"},"message":"Refactored code","distinct":false,"url":"https://api.github.com/repos/googleinterns/gpay-virtual-queue/commits/5344b686f26ec56ec7cdc142f81c5a48da4fa660"},{"sha":"4e10b6026fa3b0f1df223632f4e47407c64d9ea5","author":{"email":"ikoder@google.com","name":"ikoder"},"message":"Add delete confirmation","distinct":false,"url":"https://api.github.com/repos/googleinterns/gpay-virtual-queue/commits/4e10b6026fa3b0f1df223632f4e47407c64d9ea5"},{"sha":"6227bf8f07ef9aaa5f91e5a53a6c9153ac8bacb2","author":{"email":"ikoder@google.com","name":"ikoder"},"message":"Refactored code","distinct":false,"url":"https://api.github.com/repos/googleinterns/gpay-virtual-queue/commits/6227bf8f07ef9aaa5f91e5a53a6c9153ac8bacb2"},{"sha":"a6d4414810fa478562de178ebcdd7745bcd987a5","author":{"email":"43103463+stringtheory1234@users.noreply.github.com","name":"stringtheory1234"},"message":"Merge pull request #44 from googleinterns/add-SpecificShop-shopOwner\n\nAdd Specific Shop for Shop Owner feature","distinct":true,"url":"https://api.github.com/repos/googleinterns/gpay-virtual-queue/commits/a6d4414810fa478562de178ebcdd7745bcd987a5"}]},"public":true,"created_at":"2020-06-23T05:09:30Z","org":{"id":63743512,"login":"googleinterns","gravatar_id":"","url":"https://api.github.com/orgs/googleinterns","avatar_url":"https://avatars.githubusercontent.com/u/63743512?"}},{"id":"12705603156","type":"CreateEvent","actor":{"id":10232178,"login":"webhacking","display_login":"webhacking","gravatar_id":"","url":"https://api.github.com/users/webhacking","avatar_url":"https://avatars.githubusercontent.com/u/10232178?"},"repo":{"id":274314226," ...

# %%
import json

url = 'https://api.github.com/events'
r = requests.get(url)
r = json.loads(r.text)
#print(r[0]['id'])
print(r)
# Out:
# [{'id': '12705607901', 'type': 'WatchEvent', 'actor': {'id': 13575051, 'login': 'jmdevin', 'display_login': 'jmdevin', 'gravatar_id': '', 'url': 'https://api.github.com/users/jmdevin', 'avatar_url': 'https://avatars.githubusercontent.com/u/13575051?'}, 'repo': {'id': 48246447, 'name': 'analysis-tools-dev/static-analysis', 'url': 'https://api.github.com/repos/analysis-tools-dev/static-analysis'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2020-06-23T05:10:21Z', 'org': {'id': 62759712, 'login': 'analysis-tools-dev', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/analysis-tools-dev', 'avatar_url': 'https://avatars.githubusercontent.com/u/62759712?'}}, {'id': '12705607882', 'type': 'PushEvent', 'actor': {'id': 2895704, 'login': 'lichtwellenreiter', 'display_login': 'lichtwellenreiter', 'gravatar_id': '', 'url': 'https://api.github.com/users/lichtwellenreiter', 'avatar_url': 'https://avatars.githubusercontent.com/u/2895704?'}, 'repo': {'id': 244471079, 'name': 'lichtwellenreiter/alfred', 'url': 'https://api.github.com/repos/lichtwellenreiter/alfred'}, 'payload': {'push_id': 5269198901, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/master', 'head': '04364ca80e714511aaaaa00a8ee3cbff5da0b8a3', 'before': '042aec18fd22d10ad61f0f141418d4ca7a9f335e', 'commits': [{'sha': '04364ca80e714511aaaaa00a8ee3cbff5da0b8a3', 'author': {'email': 'florianjeremias@gmail.com', 'name': 'Florian Thiévent'}, 'message': 'removed .DS_Store', 'distinct': True, 'url': 'https://api.github.com/repos/lichtwellenreiter/alfred/commits/04364ca80e714511aaaaa00a8ee3cbff5da0b8a3'}]}, 'public': True, 'created_at': '2020-06-23T05:10:21Z'}, {'id': '12705607885', 'type': 'PushEvent', 'actor': {'id': 917628, 'login': 'tripodsan', 'display_login': 'tripodsan', 'gravatar_id': '', 'url': 'https://api.github.com/users/tripodsan', 'avatar_url': 'https://avatars.githubusercontent.com/u/917628?'}, 'repo': {'id': 223290062, 'name': 'adobe/openwhisk-action-logger', 'url': 'https://api.github.com/repos/adobe/openwhisk-action-logger'}, 'payload': {'push_id': 5269198903, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/master', 'head': '2c4ac1496231dae8bd859abfdf31733df329f72f', 'before': '95161bad3206ac9fe51ac3869d27a29288d91a10', 'commits': [{'sha': '2c4ac1496231dae8bd859abfdf31733df329f72f', 'author': {'email': '29139614+renovate[bot]@users.noreply.github.com', 'name': 'renovate[bot]'}, 'message': 'chore(deps): update external (#67)\n\nCo-authored-by: Renovate Bot <bot@renovateapp.com>', 'distinct': True, 'url': 'https://api.github.com/repos/adobe/openwhisk-action-logger/commits/2c4ac1496231dae8bd859abfdf31733df329f72f'}]}, 'public': True, 'created_at': '2020-06-23T05:10:21Z', 'org': {'id': 476009, 'login': 'adobe', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/adobe', 'avatar_url': 'https://avatars.githubusercontent.com/u/476009?'}}, {'id': '12705607888', 'type': 'IssuesEvent', 'actor': {'id': 29713643, 'login': 'autotester-one', 'display_login': 'autotester-one', 'gravatar_id': '', 'url': 'https://api.github.com/users/autotester-one', 'avatar_url': 'https://avatars.githubusercontent.com/u/29713643?'}, 'repo': {'id': 274314179, 'name': 'autotester-one/staging-integration-tests-1592888947727', 'url': 'https://api.github.com/repos/autotester-one/staging-integration-tests-1592888947727'}, 'payload': {'action': 'opened', 'issue': {'url': 'https://api.github.com/repos/autotester-one/staging-integration-tests-1592888947727/issues/3', 'repository_url': 'https://api.github.com/repos/autotester-one/staging-integration-tests-1592888947727', 'labels_url': 'https://api.github.com/repos/autotester-one/staging-integration-tests-1592888947727/issues/3/labels{/name}', 'comments_url': 'https://api.github.com/repos/autotester-one/staging-integration-tests-1592888947727/issues/3/comments', 'events_url': 'https://api.github.com/repos/autotester-one/staging-integration-tests-1592888947727/issues/3/events', 'html_url': 'https://github.com/autotester-one/staging ...

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests
import json

url = 'http://odata.wra.gov.tw/v4/RealtimeWaterLevel'
result = requests.get(url)
result = json.loads(result.text)
record_dict = dict()

for item in result['value']:
    if item['RecordTime'] in record_dict:
        record_dict[item['RecordTime']].append(item['WaterLevel'])
    else: 
        record_dict.setdefault(item['RecordTime'], []).append(item['WaterLevel'])

print(record_dict)
# Out:
# {'Dec 11, 2019 2:50:00 PM': [145.15, 226.25, 1.28, 25.73, 4.48, 224.21, 92.83, 164.37, 32.2, 138.73, 740.49, 26.75, 2.98, 109.97, 0.7, 266.23, 248.86, 38.99, 0.14, 261.61, 0.1, 43.48, 10.14, 32.01, 0.05, 124.1, 65.83, 4.85, 23.04, 79.32, 23.4, 0.19, 5.62, 0.11, 106.73, -0.15, 1.76, 10.01, 20.45, 0.54, 0.03, 175.97, 11.27, 69.07, 13.13, 27.2, 39.76, 145.89, 752.39, 0.16, 48.29, 145.06, 0.59, 20.76, 1068.94, 380.46, 95.66, 259.67, 78.22, 21.23, 50.6, 72.35, 220.79, 317.97, 19.39, 79.83, 639.41, 440.47, 97.9, 15.74, 91.76, 83.01, 622.43, 318.68, 50.08, 704.2, 282.05, 19.29, 0.37, 191.55, 58.49, 54.19, 169.81, -1.01, 7.38, 12.12, 263.49, 22.09, 41], 'Dec 11, 2019 2:20:00 PM': [1.57, 0.13, 26.14, 278.47], 'Dec 11, 2019 9:50:00 AM': [12.13, 187.7, 470.82, 20.5, 346.5], 'Dec 11, 2019 2:55:00 PM': [49.11], 'Dec 11, 2019 2:40:00 PM': [310.14]}
