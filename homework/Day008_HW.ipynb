# %% [markdown]
# # 靜態網頁的資料爬蟲策略
#
#
# * 了解靜態網頁的資料爬蟲策略
# * 認識適用於靜態網頁爬蟲的相關套件工具：Request
# * 認識適用於靜態網頁爬蟲的相關套件工具：BeatifulSoup

# %% [markdown]
# ## 作業目標
#
# 利用 Request + BeatifulSoup 爬取下列兩個網站內容並解析：
#
# 1. Dcared 網址： https://www.dcard.tw/f
# 2. 知乎： https://www.zhihu.com/explore
#
# 並且回答下面問題：
#
# 1. Request 取回之後該怎麼取出資料，資料型態是什麼？
# 2. 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？
# 3. 觀察一下知乎回來的資料好像有點怪怪的，該怎麼解決？

# %% [markdown]
# ### 1. Dcard 網址： https://www.dcard.tw/f

# %%
import requests
from bs4 import BeautifulSoup as bf

# %%
url = 'https://www.dcard.tw/f'

r = requests.get(url)

r.encoding = 'utf-8'
print(r.text[0:3000])
# Out:
# <!DOCTYPE html><html lang="zh-TW"><head prefix="og: http://ogp.me/ns#" itemscope="" itemType="https://schema.org/WebSite"><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1"/><meta name="apple-mobile-web-app-status-bar-style" content="default"/><link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap" rel="stylesheet"/><meta name="application-name" content="Dcard"/><meta name="apple-itunes-app" content="app-id=951353454"/><meta name="theme-color" content="#006aa6"/><meta name="mobile-web-app-capable" content="yes"/><meta name="apple-mobile-web-app-capable" content="yes"/><meta name="supported-color-schemes" content="light"/><meta property="fb:app_id" content="211628828926493"/><meta property="fb:pages" content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764"/><meta property="al:ios:app_store_id" content="951353454"/><meta property="al:ios:app_name" content="Dcard"/><meta property="al:android:package" content="com.sparkslab.dcardreader"/><meta property="al:android:app_name" content="Dcard"/><link rel="manifest" href="/_next/static/manifest.json"/><link rel="icon" type="image/png" sizes="16x16" href="/_next/static/media/icon-16-1daa7474e5fe761a7239d12c56b88680.png"/><link rel="icon" type="image/png" sizes="24x24" href="/_next/static/media/icon-24-7bfd8a52a6756e15edaa617b106a5c55.png"/><link rel="icon" type="image/png" sizes="32x32" href="/_next/static/media/icon-32-54392e6e864b1f822d54a543ee54a0f9.png"/><link rel="icon" type="image/png" sizes="192x192" href="/_next/static/media/icon-192-49149beb434e1f6bccac918f6608564c.png"/><link rel="apple-touch-icon" type="image/png" sizes="57x57" href="/_next/static/media/icon-57-c95fcd930b41dbc6de0495348939582f.png"/><link rel="apple-touch-icon" type="image/png" sizes="72x72" href="/_next/static/media/icon-72-69b64cb9aadc811dce34ea6ac772cd8f.png"/><link rel="apple-touch-icon" type="image/png" sizes="76x76" href="/_next/static/media/icon-76-67203a784694f8378d2f51f24970e2f7.png"/><link rel="apple-touch-icon" type="image/png" sizes="114x114" href="/_next/static/media/icon-114-c58f911deb58868e8cc68ea1e09cc688.png"/><link rel="apple-touch-icon" type="image/png" sizes="120x120" href="/_next/static/media/icon-120-f3ada61716c0cc460c2cbe72b18fb9b4.png"/><link rel="apple-touch-icon" type="image/png" sizes="144x144" href="/_next/static/media/icon-144-679d873aa4b58f1117915545d3fdfa1d.png"/><link rel="apple-touch-icon" type="image/png" sizes="152x152" href="/_next/static/media/icon-152-b7ec982f1f49f590c97611e0e5e9f7f3.png"/><link rel="apple-touch-icon" type="image/png" sizes="180x180" href="/_next/static/media/icon-180-2665760e1b88b5af7a3cfbdc532bae20.png"/><link rel="shortcut icon" type="image/png" href="/_next/static/media/icon-32-54392e6e864b1f822d54a543ee54a0f9.png"/><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.

# %%
print('Request 取回之後該怎麼取出資料，資料型態是什麼？ =>')

print(type(r.text))
# Out:
# Request 取回之後該怎麼取出資料，資料型態是什麼？ =>
# <class 'str'>

# %%
print('為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ => ')

soup = bf(r.text)
print(type(soup))
#print(soup.title.name)
#print(soup.title.string)
print(soup.prettify())
# Out:
# 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ =>
# <class 'bs4.BeautifulSoup'>
# <!DOCTYPE html>
# <html data-hairline="true" data-theme="light" lang="zh">
#  <head>
#   <meta charset="utf-8"/>
#   <title data-react-helmet="true">
#    发现 - 知乎
#   </title>
#   <meta content="width=device-width,initial-scale=1,maximum-scale=1" name="viewport"/>
#   <meta content="webkit" name="renderer"/>
#   <meta content="webkit" name="force-rendering"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="FTeR0c8arOPKh8c5DYh_9uu98_zJbaWw53J-Sch9MTg" name="google-site-verification"/>
#   <meta content="有问题，上知乎。知乎，可信赖的问答社区，以让每个人高效获得可信赖的解答为使命。知乎凭借认真、专业和友善的社区氛围，结构化、易获得的优质内容，基于问答的内容生产方式和独特的社区机制，吸引、聚集了各行各业中大量的亲历者、内行人、领域专家、领域爱好者，将高质量的内容透过人的节点来成规模地生产和分享。用户通过问答等交流方式建立信任和连接，打造和提升个人影响力，并发现、获得新机会。" name="description" property="og:description"/>
#   <link data-react-helmet="true" href="https://static.zhihu.com/heifetz/assets/apple-touch-icon-152.67c7b278.png" rel="apple-touch-icon"/>
#   <link data-react-helmet="true" href="https://static.zhihu.com/heifetz/assets/apple-touch-icon-152.67c7b278.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link data-react-helmet="true" href="https://static.zhihu.com/heifetz/assets/apple-touch-icon-120.b3e6278d.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link data-react-helmet="true" href="https://static.zhihu.com/heifetz/assets/apple-touch-icon-76.7a750095.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link data-react-helmet="true" href="https://static.zhihu.com/heifetz/assets/apple-touch-icon-60.a4a761d4.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="https://static.zhihu.com/static/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://static.zhihu.com/static/search.xml" rel="search" title="知乎" type="application/opensearchdescription+xml"/>
#   <link href="//static.zhimg.com" rel="dns-prefetch"/>
#   <link href="//pic1.zhimg.com" rel="dns-prefetch"/>
#   <link href="//pic2.zhimg.com" rel="dns-prefetch"/>
#   <link href="//pic3.zhimg.com" rel="dns-prefetch"/>
#   <link href="//pic4.zhimg.com" rel="dns-prefetch"/>
#   <style>
#    .u-safeAreaInset-top {
#   height: constant(safe-area-inset-top) !important;
#   height: env(safe-area-inset-top) !important;
#
# }
# .u-safeAreaInset-bottom {
#   height: constant(safe-area-inset-bottom) !important;
#   height: env(safe-area-inset-bottom) !important;
#
# }
#   </style>
#   <link href="https://static.zhihu.com/heifetz/main.app.216a26f4.7e11184c0f1e67dc3a93.css" rel="stylesheet"/>
#   <link href="https://static.zhihu.com/heifetz/main.explore-routes.216a26f4.588e77e0125b1a185746.css" rel="stylesheet"/>
#   <script crossorigin="anonymous" data-sentry-config="{&quot;dsn&quot;:&quot;https://2d8d764432cc4f6fb3bc78ab9528299d@crash2.zhihu.com/1224&quot;,&quot;sampleRate&quot;:0.1,&quot;release&quot;:&quot;29-d53dd597&quot;,&quot;ignoreErrorNames&quot;:[&quot;NetworkError&quot;,&quot;SecurityError&quot;],&quot;ignoreErrors&quot;:[&quot;origin message&quot;,&quot;Network request failed&quot;,&quot;Loading chunk&quot;,&quot;这个系统不支持该功能。&quot;,&quot;Can't find variable: webkit&quot;,&quot;Can't find variable: $&quot;,&quot;内存不足&quot;,&quot;out of memory&quot;,&quot;DOM Exception 18&quot;,&quot;The operation is insecure&quot;,&quot;[object Event]&quot;,&quot;[object FileError]&quot;,&quot;[object DOMError]&quot;,&quot;[object Object]&quot;,&quot;拒绝访问。&quot;,&quot;Maximum call stack size exceeded&quot;,&quot;UploadError&quot;,&quot;无法 fetch&quot;,&quot;draft-js&quot;,&quot;缺少 JavaScript 对象&quot;,&quot;componentWillEnter&quot;,&quot;componentWillLeave&quot;,&quot;componentWillAppear&quot;,&quot;getInlineStyleAt&quot;,&quot;getCharacterList&quot;],&quot;whitelistUrls&quot;:[&quot;static.zhihu.com&quot;]}" defer="" src="https://unpkg.zhimg.com/@cfe/sentry-script@latest/dist/init.js">
#   </script>
#  </head>
#  <body>
#   <div id="root">
#    <div>
#     <div class="LoadingBar">
#     </div>
#     <div>
#      <header class="Sticky AppHeader" data-za-module="TopNavBar" role="banner">
#       <div class="AppHeader-inner">
#        <a aria-label="知乎" href="//www.zhihu.com">
#         <svg fill="#0084FF" height="30" viewbox="0 0 200 91" width="64">
#          <path d="M53.29 80.035l7.32.002 2.41 8.24 13.128-8.24h15.477v-67.98H53.29v67.978zm7.79-60.598h22.756v53.22h-8.73l-8.718 5.473-1.587-5.46-3.72-.012v-53.22zM46.818 43.162h-16.35c.545-8.467.687-16.12.687-22.955h15.987s.615-7.05-2.68-6.97H16.807c1.09-4.1 2.46-8.332 4.1-12.708 0 0-7.523 0-10.085 6.74-1.06 2.78-4.128 13.48-9.592 24.41 1.84-.2 7.927-.37 11.512-6.94.66-1.84.785-2.08 1.605-4.54h9.02c0 3.28-.374 20.9-.526 22.95H6.51c-3.67 0-4.863 7.38-4.863 7.38H22.14C20.765 66.11 13.385 79.24 0 89.62c6.403 1.828 12.784-.29 15.937-3.094 0 0 7.182-6.53 11.12-21.64L43.92 85.18s2.473-8.402-.388-12.496c-2.37-2.788-8.768-10.33-11.496-13.064l-4.57 3.627c1.363-4.368 2.183-8.61 2.46-12.71H49.19s-.027-7.38-2.372-7.38zm128.752-.502c6.51-8.013 14.054-18.302 14.054-18.302s-5.827-4.625-8.556-1.27c-1.874 2.548-11.51 15.063-11.51 15.063l6.012 4.51zm-46.903-18.462c-2.814-2.577-8.096.667-8.096.667s12.35 17.2 12.85 17.953l6.08-4.29s-8.02-11.752-10.83-14.33zM199.99 46.5c-6.18 0-40.908.292-40.953.292v-31.56c1.503 0 3.882-.124 7.14-.376 12.773-.753 21.914-1.25 27.427-1.504 0 0 3.817-8.496-.185-10.45-.96-.37-7.24 1.43-7.24 1.43s-51.63 5.153-72.61 5.64c.5 2.756 2.38 5.336 4.93 6.11 4.16 1.087 7.09.53 15.36.277 7.76-.5 13.65-.76 17.66-.76v31.19h-41.71s.88 6.97 7.97 7.14h33.73v22.16c0 4.364-3.498 6.87-7.65 6.6-4.4.034-8.15-.36-13.027-.566.623 1.24 1.977 4.496 6.035 6.824 3.087 1.502 5.054 2.053 8.13 2.053 9.237 0 14.27-5.4 14.027-14.16V53.93h38.235c3.026 0 2.72-7.432 2.72-7.432z" fill-rule="evenodd">
#          </path>
#         </svg>
#        </a>
#        <ul class="Tabs AppHeader-Tabs" role="navigation">
#         <li class="Tabs-item AppHeader-Tab Tabs-item--noMeta" role="tab">
#          <a class="Tabs-link AppHeader-TabsLink" data-za-not-track-link="true" href="//www.zhihu.com/">
#           首页
#          </a>
#         </li>
#         <li class="Tabs-item AppHeader-Tab Tabs-item--noMeta" role="tab">
#          <a class="Tabs-link AppHeader-TabsLink is-active" data-za-not-track-link="true" href="//www.zhihu.com/explore">
#           发现
#          </a>
#         </li>
#         <li class="Tabs-item AppHeader-Tab Tabs-item--noMeta" role="tab">
#          <a class="Tabs-link AppHeader-TabsLink" data-za-not-track-link="true" href="//www.zhihu.com/question/waiting">
#           等你来答
#          </a>
#         </li>
#        </ul>
#        <div class="SearchBar" data-za-module="PresetWordItem" role="search">
#         <div class="SearchBar-toolWrapper">
#          <form class="SearchBar-tool">
#           <div>
#            <div class="Popover">
#             <label class="SearchBar-input Input-wrapper Input-wrapper--grey">
#              <input aria-activedescendant="null--1" aria-autocomplete="list" aria-expanded="false" aria-haspopup="true" aria-owns="null-content" autocomplete="off" class="Input" id="null-toggle" maxlength="100" placeholder="" role="combobox" type="text" value=""/>
#              <button aria-label="搜索" class="Button SearchBar-searchButton Button--primary" type="button">
#               <span style="display:inline-flex;align-items:center">
#                ​
#                <svg class="Zi Zi--Search SearchBar-searchIcon" fill="currentColor" height="18" viewbox="0 0 24 24" width="18">
#                 <path d="M17.068 15.58a8.377 8.377 0 0 0 1.774-5.159 8.421 8.421 0 1 0-8.42 8.421 8.38 8.38 0 0 0 5.158-1.774l3.879 3.88c.957.573 2.131-.464 1.488-1.49l-3.879-3.878zm-6.647 1.157a6.323 6.323 0 0 1-6.316-6.316 6.323 6.323 0 0 1 6.316-6.316 6.323 6.323 0 0 1 6.316 6.316 6.323 6.323 0 0 1-6.316 6.316z" fill-rule="evenodd">
#                 </path>
#                </svg>
#               </span>
#              </button>
#             </label>
#            </div>
#           </div>
#          </form>
#         </div>
#        </div>
#        <div class="AppHeader-userInfo">
#         <div class="AppHeader-profile">
#          <div>
#           <button class="Button AppHeader-login Button--blue" type="button">
#            登录
#           </button>
#           <button class="Button Button--primary Button--blue" type="button">
#            加入知乎
#           </button>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div>
#       </div>
#      </header>
#     </div>
#     <main class="App-main" role="main">
#      <div>
#       <div class="Sticky">
#       </div>
#      </div>
#      <div class="ExploreHomePage">
#       <div class="ExploreHomePage-ContentSection ExploreHomePage-section" id="special">
#        <div class="ExploreHomePage-ContentSection-header">
#         <svg class="Zi Zi--LabelSpecial" fill="currentColor" height="36" viewbox="0 0 24 24" width="36">
#          <path d="M7.667 3.667h11.466a1.2 1.2 0 0 1 1.2 1.2v13.066a2.4 2.4 0 0 1-2.4 2.4H6.467V4.867a1.2 1.2 0 0 1 1.2-1.2zM4.2 9.619h1.689v10.714H5.4a2.4 2.4 0 0 1-2.4-2.4V10.82a1.2 1.2 0 0 1 1.2-1.2zm5.178-2.38a.6.6 0 0 0-.6.6v.585a.6.6 0 0 0 .6.6h8.044a.6.6 0 0 0 .6-.6v-.586a.6.6 0 0 0-.6-.6H9.378zm0 3.57a.6.6 0 0 0-.6.6v.586a.6.6 0 0 0 .6.6h8.044a.6.6 0 0 0 .6-.6v-.585a.6.6 0 0 0-.6-.6H9.378zm0 3.572a.6.6 0 0 0-.6.6v.586a.6.6 0 0 0 .6.6h4.578a.6.6 0 0 0 .6-.6v-.586a.6.6 0 0 0-.6-.6H9.378z" fill-rule="evenodd">
#          </path>
#         </svg>
#         <span>
#          最新专题
#         </span>
#        </div>
#        <div class="ExploreHomePage-ContentSection-body">
#         <div class="ExploreHomePage-specials">
#          <div class="ExploreHomePage-specialsLogin">
#           <div class="ExploreHomePage-specialsLoginImg">
#            <img src="https://static.zhihu.com/heifetz/assets/loginBackgroundImg.2c81e205.png"/>
#           </div>
#           <div class="ExploreHomePage-specialsLoginTitle">
#            登录一下
#           </div>
#           <div class="ExploreHomePage-specialsLoginDes">
#            更多精彩内容等你发现
#           </div>
#           <div class="ExploreHomePage-specialsLoginBottomButton">
#            <button class="Button ExploreHomePage-specialsLoginButton" type="button">
#             登录
#            </button>
#           </div>
#          </div>
#          <div class="ExploreSpecialCard ExploreHomePage-specialCard">
#           <a class="ExploreSpecialCard-banner" data-za-detail-view-id="5792" href="/special/19664322" rel="noreferrer noopener" target="_blank">
#            <img src="https://pic2.zhimg.com/100/v2-7d9d19e6c16759b89eeaf7eec45e4205_hd.png"/>
#           </a>
#           <div class="ExploreSpecialCard-header">
#            <div class="ExploreSpecialCard-info">
#             <a class="ExploreSpecialCard-title" data-za-detail-view-id="5792" href="/special/19664322" rel="noreferrer noopener" target="_blank">
#              10 个直戳买车痛点的问题！
#             </a>
#             <div class="ExploreSpecialCard-count">
#              <span>
#               3 小时前
#               <!-- -->
#               更新
#              </span>
#              <span>
#               3,783,004
#               <!-- -->
#               浏览
#              </span>
#             </div>
#            </div>
#            <div class="ExploreSpecialCard-followButton">
#             <button class="ExploreFollowButton">
#              关注专题
#             </button>
#            </div>
#           </div>
#           <div class="ExploreSpecialCard-contentList">
#            <div class="ExploreSpecialCard-contentItem">
#             <a class="ExploreSpecialCard-contentTag" data-za-detail-view-id="5793" href="/special/19664322#NewsSpecial-SubModule-1260616890982203392" rel="noopener noreferrer" target="blank">
#              买车前「义务教育」
#             </a>
#             <a class="ExploreSpecialCard-contentTitle" data-za-detail-view-id="5794" href="/answer/843094533" rel="noopener noreferrer" target="blank">
#              新手买车如何不被坑？
#             </a>
#            </div>
#            <div class="ExploreSpecialCard-contentItem">
#             <a class="ExploreSpecialCard-contentTag" data-za-detail-view-id="5793" href="/special/19664322#NewsSpecial-SubModule-1260616933449789440" rel="noopener noreferrer" target="blank">
#              买车时「如何避坑」
#             </a>
#             <a class="ExploreSpecialCard-contentTitle" data-za-detail-view-id="5794" href="/answer/92983834" rel="noopener noreferrer" target="blank">
#              去 4S 店买车需要知道哪些内幕以避免被忽悠？
#             </a>
#            </div>
#            <div class="ExploreSpecialCard-contentItem">
#             <a class="ExploreSpecialCard-contentTag" data-za-detail-view-id="5793" href="/special/19664322#NewsSpecial-SubModule-1260617008456241152" rel="noopener noreferrer" target="blank">
#              提车后「正确用车」
#             </a>
#             <a class="ExploreSpecialCard-contentTitle" data-za-detail-view-id="5794" href="/answer/729926478" rel="noopener noreferrer" target="blank">
#              提车时有哪些注意事项？
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="ExploreSpecialCard ExploreHomePage-specialCard">
#           <a class="ExploreSpecialCard-banner" data-za-detail-view-id="5792" href="/special/21302248" rel="noreferrer noopener" target="_blank">
#            <img src="https://pic1.zhimg.com/100/v2-20d12cab96faff2fe3cc2eb285987ec4_hd.png"/>
#           </a>
#           <div class="ExploreSpecialCard-header">
#            <div class="ExploreSpecialCard-info">
#             <a class="ExploreSpecialCard-title" data-za-detail-view-id="5792" href="/special/21302248" rel="noreferrer noopener" target="_blank">
#              在知乎发视频，可容易了
#             </a>
#             <div class="ExploreSpecialCard-count">
#              <span>
#               昨天 10:47
#               <!-- -->
#               更新
#              </span>
#              <span>
#               41,915
#               <!-- -->
#               浏览
#              </span>
#             </div>
#            </div>
#            <div class="ExploreSpecialCard-followButton">
#             <button class="ExploreFollowButton">
#              关注专题
#             </button>
#            </div>
#           </div>
#           <div class="ExploreSpecialCard-contentList">
#            <div class="ExploreSpecialCard-contentItem">
#             <a class="ExploreSpecialCard-contentTag" data-za-detail-view-id="5793" href="/special/21302248#NewsSpecial-SubModule-1259181050351730688" rel="noopener noreferrer" target="blank">
#              训练营课程回放
#             </a>
#             <a class="ExploreSpecialCard-contentTitle" data-za-detail-view-id="5794" href="/null/1259181647473602560" rel="noopener noreferrer" target="blank">
#              视频制作课程
#             </a>
#            </div>
#            <div class="ExploreSpecialCard-contentItem">
#             <a class="ExploreSpecialCard-contentTag" data-za-detail-view-id="5793" href="/special/21302248#NewsSpecial-SubModule-1259181050351730688" rel="noopener noreferrer" target="blank">
#              训练营课程回放
#             </a>
#             <a class="ExploreSpecialCard-contentTitle" data-za-detail-view-id="5794" href="/null/1259182505330610176" rel="noopener noreferrer" target="blank">
#              知乎视频创作手册
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="ExploreSpecialCard ExploreHomePage-specialCard">
#           <a class="ExploreSpecialCard-banner" data-za-detail-view-id="5792" href="/special/19597895" rel="noreferrer noopener" target="_blank">
#            <img src="https://pic2.zhimg.com/100/v2-0872bd472ab138d889f2a542bd778569_hd.png"/>
#           </a>
#           <div class="ExploreSpecialCard-header">
#            <div class="ExploreSpecialCard-info">
#             <a class="ExploreSpecialCard-title" data-za-detail-view-id="5792" href="/special/19597895" rel="noreferrer noopener" target="_blank">
#              小蓝书·高考考前锦囊
#             </a>
#             <div class="ExploreSpecialCard-count">
#              <span>
#               昨天 13:57
#               <!-- -->
#               更新
#              </span>
#              <span>
#               81,008,551
#               <!-- -->
#               浏览
#              </span>
#             </div>
#            </div>
#            <div class="ExploreSpecialCard-followButton">
#             <button class="ExploreFollowButton">
#              关注专题
#             </button>
#            </div>
#           </div>
#           <div class="ExploreSpecialCard-contentList">
#            <div class="ExploreSpecialCard-contentItem">
#             <a class="ExploreSpecialCard-contentTag" data-za-detail-view-id="5793" href="/special/19597895#NewsSpecial-SubModule-1258017504879628288" rel="noopener noreferrer" target="blank">
#              缓解焦虑
#             </a>
#             <a class="ExploreSpecialCard-contentTitle" data-za-detail-view-id="5794" href="/question/37672919" rel="noopener noreferrer" target="blank">
#              高考生，你为什么越努力越焦虑？
#             </a>
#            </div>
#            <div class="ExploreSpecialCard-contentItem">
#             <a class="ExploreSpecialCard-contentTag" data-za-detail-view-id="5793" href="/special/19597895#NewsSpecial-SubModule-1258026865447096320" rel="noopener noreferrer" target="blank">
#              减轻压力
#             </a>
#             <a class="ExploreSpecialCard-contentTitle" data-za-detail-view-id="5794" href="/answer/416175255" rel="noopener noreferrer" target="blank">
#              压力很大怎么办？
#             </a>
#            </div>
#            <div class="ExploreSpecialCard-contentItem">
#             <a class="ExploreSpecialCard-contentTag" data-za-detail-view-id="5793" href="/special/19597895#NewsSpecial-SubModule-1258032178991902720" rel="noopener noreferrer" target="blank">
#              调整心态
#             </a>
#             <a class="ExploreSpecialCard-contentTitle" data-za-detail-view-id="5794" href="/question/399936928" rel="noopener noreferrer" target="blank">
#              快高考了心态崩了怎么办?
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="ExploreSpecialCard ExploreHomePage-specialCard">
#           <a class="ExploreSpecialCard-banner" data-za-detail-view-id="5792" href="/special/19797894" rel="noreferrer noopener" target="_blank">
#            <img src="https://pic1.zhimg.com/100/v2-8cc5728e4bab237d528abc1e8c5c9408_hd.png"/>
#           </a>
#           <div class="ExploreSpecialCard-header">
#            <div class="ExploreSpecialCard-info">
#             <a class="ExploreSpecialCard-title" data-za-detail-view-id="5792" href="/special/19797894" rel="noreferrer noopener" target="_blank">
#              驶向未来 ︳汽车新十年
#             </a>
#             <div class="ExploreSpecialCard-count">
#              <span>
#               06-21
#               <!-- -->
#               更新
#              </span>
#              <span>
#               9,310,058
#               <!-- -->
#               浏览
#              </span>
#             </div>
#            </div>
#            <div class="ExploreSpecialCard-followButton">
#             <button class="ExploreFollowButton">
#              关注专题
#             </button>
#            </div>
#           </div>
#           <div class="ExploreSpecialCard-contentList">
#            <div class="ExploreSpecialCard-contentItem">
#             <a class="ExploreSpecialCard-contentTag" data-za-detail-view-id="5793" href="/special/19797894#NewsSpecial-SubModule-1257689857126182912" rel="noopener noreferrer" target="blank">
#              未来「新趋势」
#             </a>
#             <a class="ExploreSpecialCard-contentTitle" data-za-detail-view-id="5794" href="/question/401061039" rel="noopener noreferrer" target="blank">
#              智能汽车+新零售业态，是趋势还是伪命题？
#             </a>
#            </div>
#            <div class="ExploreSpecialCard-contentItem">
#             <a class="ExploreSpecialCard-contentTag" data-za-detail-view-id="5793" href="/special/19797894#NewsSpecial-SubModule-1257689909034332160" rel="noopener noreferrer" target="blank">
#              技术「新势力」
#             </a>
#             <a class="ExploreSpecialCard-contentTitle" data-za-detail-view-id="5794" href="/question/53163627" rel="noopener noreferrer" target="blank">
#              该如何评价新能源汽车的电池性能和安全性？
#             </a>
#            </div>
#            <div class="ExploreSpecialCard-contentItem">
#             <a class="ExploreSpecialCard-contentTag" data-za-detail-view-id="5793" href="/special/19797894#NewsSpecial-SubModule-1257689956048293888" rel="noopener noreferrer" target="blank">
#              驾驶「新体验」
#             </a>
#             <a class="ExploreSpecialCard-contentTitle" data-za-detail-view-id="5794" href="/question/315895731" rel="noopener noreferrer" target="blank">
#              买了新能源车后，你在日常出行上有哪些变化？究竟是利多还是弊多？
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="ExploreHomePage-ContentSection-moreButton">
#         <a data-za-detail-view-id="5796" href="/special/all" rel="noreferrer noopener" target="_blank">
#          查看更多专题
#          <svg class="Zi Zi--ArrowRight" fill="currentColor" height="25" viewbox="0 0 24 24" width="25">
#           <path d="M9.218 16.78a.737.737 0 0 0 1.052 0l4.512-4.249a.758.758 0 0 0 0-1.063L10.27 7.22a.737.737 0 0 0-1.052 0 .759.759 0 0 0-.001 1.063L13 12l-3.782 3.716a.758.758 0 0 0 0 1.063z" fill-rule="evenodd">
#           </path>
#          </svg>
#         </a>
#        </div>
#       </div>
#       <div class="ExploreHomePage-ContentSection ExploreHomePage-section" id="roundtable">
#        <div class="ExploreHomePage-ContentSection-header">
#         <svg class="Zi Zi--LabelRoundtable" fill="currentColor" height="36" viewbox="0 0 24 24" width="36">
#          <path d="M12 21.333a9.333 9.333 0 1 1 0-18.666 9.333 9.333 0 0 1 0 18.666zm-.66-11.287c.332.385.609.77.775 1.21.055-.054.665-.99.72-1.706.055-.385.126-1.616-.443-2.367-.443-.496-1.219-.77-1.884-.55a1.788 1.788 0 0 0-1.33 2.036c.887.276 1.607.771 2.161 1.377zm-1.33 1.541c.443-.055.941-.11 1.44 0 0-.055-.484-.936-1.108-1.486-.665-.496-1.33-.973-2.216-.771-.72.11-1.723.77-1.55 2.092.11.606.553 1.101 1.162 1.321.61-.605 1.44-1.046 2.272-1.156zm2.714.165c.056 0 1.164.055 1.828-.165.72-.275 1.412-.68 1.773-1.541.11-.276.23-1.248-.443-1.872-.72-.716-1.717-.716-2.438-.165.222.825.063 1.966-.11 2.532-.103.348-.333.88-.61 1.211zm-1.44.55c-.056 0-1.33.056-1.828.221-.72.275-1.447.668-1.773 1.541-.11.276-.21 1.26.443 1.872.665.661 1.718.661 2.438.11-.295-.811-.166-1.761.055-2.477.166-.495.388-.936.665-1.266zm5.041-.99c-.665.605-1.44.99-2.327 1.211-.443.055-.941.11-1.44 0 0 .055.554.991 1.108 1.431.665.496 1.385.771 2.216.771.72-.11 1.678-.692 1.551-2.092-.055-.605-.554-1.101-1.108-1.321zm-3.656 2.642a3.475 3.475 0 0 1-.776-1.156c-.055.055-.665.991-.72 1.707-.055.385-.101 1.506.499 2.312.443.496 1.218.77 1.883.55.887-.275 1.496-1.1 1.33-2.036a5.38 5.38 0 0 1-2.216-1.377z" fill-rule="evenodd">
#          </path>
#         </svg>
#         <span>
#          圆桌讨论
#         </span>
#        </div>
#        <div class="ExploreHomePage-ContentSection-body">
#         <div class="ExploreHomePage-roundtables">
#          <div class="ExploreRoundtableCard ExploreHomePage-roundtableCard">
#           <div class="ExploreRoundtableCard-headerContainer" style="background-color:#2784BC">
#            <div class="ExploreRoundtableCard-headerBackgrounds">
#             <div style="background-image:url(https://pic4.zhimg.com/50/v2-7ec9198372c97ca40069dda387ac5b9d_hd.jpg);background-position:center">
#             </div>
#             <div style="background:linear-gradient(to right, rgba(39, 132, 188, 1) 0%, rgba(39, 132, 188, 0) 100%">
#             </div>
#             <div style="background:linear-gradient(to right, rgba(39, 132, 188, 0.5) 0%, rgba(39, 132, 188, 0) 100%">
#             </div>
#            </div>
#            <div class="ExploreRoundtableCard-header">
#             <a class="ExploreRoundtableCard-title" data-za-detail-view-id="5799" href="/roundtable/gkhy" rel="noreferrer noopener" target="_blank">
#              高考回忆录
#             </a>
#             <a class="ExploreRoundtableCard-intro" data-za-detail-view-id="5799" href="/roundtable/gkhy" rel="noreferrer noopener" target="_blank">
#              又是一年高考季，你还记得那年高考吗？想起高考，你印象最深的画面是什么？是在拼命刷题，还是最后一课与恩师的告别？是高考后的狂欢？还是报志愿时的迷茫？那些曾经无数次记起的人和事，如今却成了可望不可及的过去。你们还记得那场名为「高考」的青春吗？
#             </a>
#             <div class="ExploreRoundtableCard-info">
#              <div class="ExploreRoundtableCard-guests">
#               <img src="https://pic3.zhimg.com/50/v2-84773696fc558559694e2f414669b6d0_hd.jpg"/>
#               <img src="https://pic3.zhimg.com/50/v2-d94579f978d5ebae54c6f2d1cb55b3d1_hd.jpg"/>
#               <img src="https://pic2.zhimg.com/50/v2-58c5b1bc0a3ba399ff6b815d43ffb669_hd.jpg"/>
#               <span>
#                7
#                <!-- -->
#                位嘉宾参与
#               </span>
#              </div>
#              <div class="ExploreRoundtableCard-count">
#               <span>
#                62
#                <!-- -->
#                人关注
#               </span>
#              </div>
#             </div>
#            </div>
#            <div class="ExploreRoundtableCard-followButton">
#             <button class="ExploreFollowButton ExploreFollowButton--colored" style="color:rgba(39, 132, 188, 1)">
#              关注圆桌
#             </button>
#            </div>
#           </div>
#           <div class="ExploreRoundtableCard-questionList">
#            <div class="ExploreRoundtableCard-questionItem">
#             <a class="ExploreRoundtableCard-questionTitle" data-za-detail-view-id="5800" href="/question/403894199" rel="noopener noreferrer" target="_blank">
#              高考那年，让你印象最深刻的人是谁？
#             </a>
#             <div class="ExploreRoundtableCard-questionCounts">
#              <span>
#               15
#               <!-- -->
#               个回答
#              </span>
#             </div>
#            </div>
#            <div class="ExploreRoundtableCard-questionItem">
#             <a class="ExploreRoundtableCard-questionTitle" data-za-detail-view-id="5800" href="/question/398869657" rel="noopener noreferrer" target="_blank">
#              高考前一晚你在想什么？
#             </a>
#             <div class="ExploreRoundtableCard-questionCounts">
#              <span>
#               105
#               <!-- -->
#               个回答
#              </span>
#             </div>
#            </div>
#            <div class="ExploreRoundtableCard-questionItem">
#             <a class="ExploreRoundtableCard-questionTitle" data-za-detail-view-id="5800" href="/question/280060304" rel="noopener noreferrer" target="_blank">
#              假如现在让你重回高三，复习参加高考，你愿意吗？
#             </a>
#             <div class="ExploreRoundtableCard-questionCounts">
#              <span>
#               75
#               <!-- -->
#               个回答
#              </span>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="ExploreRoundtableCard ExploreHomePage-roundtableCard">
#           <div class="ExploreRoundtableCard-headerContainer" style="background-color:#17452C">
#            <div class="ExploreRoundtableCard-headerBackgrounds">
#             <div style="background-image:url(https://pic1.zhimg.com/50/v2-00f8805ec1d10c26f09a8f6a878c77ed_hd.jpg);background-position:center">
#             </div>
#             <div style="background:linear-gradient(to right, rgba(23, 69, 44, 1) 0%, rgba(23, 69, 44, 0) 100%">
#             </div>
#             <div style="background:linear-gradient(to right, rgba(23, 69, 44, 0.5) 0%, rgba(23, 69, 44, 0) 100%">
#             </div>
#            </div>
#            <div class="ExploreRoundtableCard-header">
#             <a class="ExploreRoundtableCard-title" data-za-detail-view-id="5799" href="/roundtable/tiyuguanjunmendegushi" rel="noreferrer noopener" target="_blank">
#              体育冠军们的故事
#             </a>
#             <a class="ExploreRoundtableCard-intro" data-za-detail-view-id="5799" href="/roundtable/tiyuguanjunmendegushi" rel="noreferrer noopener" target="_blank">
#              大家只知道冠军在赛场上的风光，而成功背后的故事却往往被人忽视。所以这里请大家分享你所知道的冠军故事，带大家一起领略冠军的成功之路和童年趣事!
#             </a>
#             <div class="ExploreRoundtableCard-info">
#              <div class="ExploreRoundtableCard-guests">
#               <img src="https://pic3.zhimg.com/50/v2-136bf993d4c92ad46de1c43e0ef6ee54_hd.jpg"/>
#               <img src="https://pic2.zhimg.com/50/v2-65c00a83d986d5c78e0fcd85ad0d86bd_hd.jpg"/>
#               <img src="https://pic2.zhimg.com/50/v2-2443ad7f5eabca1aa618518112aed597_hd.jpg"/>
#               <span>
#                6
#                <!-- -->
#                位嘉宾参与
#               </span>
#              </div>
#              <div class="ExploreRoundtableCard-count">
#               <span>
#                12
#                <!-- -->
#                人关注
#               </span>
#              </div>
#             </div>
#            </div>
#            <div class="ExploreRoundtableCard-followButton">
#             <button class="ExploreFollowButton ExploreFollowButton--colored" style="color:rgba(23, 69, 44, 1)">
#              关注圆桌
#             </button>
#            </div>
#           </div>
#           <div class="ExploreRoundtableCard-questionList">
#            <div class="ExploreRoundtableCard-questionItem">
#             <a class="ExploreRoundtableCard-questionTitle" data-za-detail-view-id="5800" href="/question/403499269" rel="noopener noreferrer" target="_blank">
#              利物浦在 2019-20 赛季首次夺得英超冠军，你有什么想说的？
#             </a>
#             <div class="ExploreRoundtableCard-questionCounts">
#              <span>
#               423
#               <!-- -->
#               个回答
#              </span>
#             </div>
#            </div>
#            <div class="ExploreRoundtableCard-questionItem">
#             <a class="ExploreRoundtableCard-questionTitle" data-za-detail-view-id="5800" href="/question/344468000" rel="noopener noreferrer" target="_blank">
#              新中国体育史上，有哪些比赛的瞬间令你沸腾？
#             </a>
#             <div class="ExploreRoundtableCard-questionCounts">
#              <span>
#               2,598
#               <!-- -->
#               个回答
#              </span>
#             </div>
#            </div>
#            <div class="ExploreRoundtableCard-questionItem">
#             <a class="ExploreRoundtableCard-questionTitle" data-za-detail-view-id="5800" href="/question/282207905" rel="noopener noreferrer" target="_blank">
#              体育史上有哪些让你「瞠目结舌」的经典失误？
#             </a>
#             <div class="ExploreRoundtableCard-questionCounts">
#              <span>
#               488
#               <!-- -->
#               个回答
#              </span>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="ExploreRoundtableCard ExploreHomePage-roundtableCard">
#           <div class="ExploreRoundtableCard-headerContainer" style="background-color:#7DB3B3">
#            <div class="ExploreRoundtableCard-headerBackgrounds">
#             <div style="background-image:url(https://pic4.zhimg.com/50/v2-90c261cf020d221f3c047d911ad1ab17_hd.jpg);background-position:center">
#             </div>
#             <div style="background:linear-gradient(to right, rgba(125, 179, 179, 1) 0%, rgba(125, 179, 179, 0) 100%">
#             </div>
#             <div style="background:linear-gradient(to right, rgba(125, 179, 179, 0.5) 0%, rgba(125, 179, 179, 0) 100%">
#             </div>
#            </div>
#            <div class="ExploreRoundtableCard-header">
#             <a class="ExploreRoundtableCard-title" data-za-detail-view-id="5799" href="/roundtable/14mark" rel="noreferrer noopener" target="_blank">
#              打卡夏日清凉色
#             </a>
#             <a class="ExploreRoundtableCard-intro" data-za-detail-view-id="5799" href="/roundtable/14mark" rel="noreferrer noopener" target="_blank">
#              炎热的夏季急需一抹清凉来解暑，有哪些是适合夏季的专属色彩呢？@知乎时尚 诚邀你加入 「夏日清凉色」挑战 14 天打卡活动。不论你擅长美妆、穿搭，还是热爱美食、生活，都希望你能在这个打卡活动中记录这一个美好夏日。
#             </a>
#             <div class="ExploreRoundtableCard-info">
#              <div class="ExploreRoundtableCard-guests">
#               <span>
#                0
#                <!-- -->
#                位嘉宾参与
#               </span>
#              </div>
#              <div class="ExploreRoundtableCard-count">
#               <span>
#                153
#                <!-- -->
#                人关注
#               </span>
#              </div>
#             </div>
#            </div>
#            <div class="ExploreRoundtableCard-followButton">
#             <button class="ExploreFollowButton ExploreFollowButton--colored" style="color:rgba(125, 179, 179, 1)">
#              关注圆桌
#             </button>
#            </div>
#           </div>
#           <div class="ExploreRoundtableCard-questionList">
#            <div class="ExploreRoundtableCard-questionItem">
#             <a class="ExploreRoundtableCard-questionTitle" data-za-detail-view-id="5800" href="/question/328128071" rel="noopener noreferrer" target="_blank">
#              什么粉底液更适合夏天呢?
#             </a>
#             <div class="ExploreRoundtableCard-questionCounts">
#              <span>
#               13
#               <!-- -->
#               个回答
#              </span>
#             </div>
#            </div>
#            <div class="ExploreRoundtableCard-questionItem">
#             <a class="ExploreRoundtableCard-questionTitle" data-za-detail-view-id="5800" href="/question/23977530" rel="noopener noreferrer" target="_blank">
#              夏季有那些高颜值降温神器？
#             </a>
#             <div class="ExploreRoundtableCard-questionCounts">
#              <span>
#               20
#               <!-- -->
#               个回答
#              </span>
#             </div>
#            </div>
#            <div class="ExploreRoundtableCard-questionItem">
#             <a class="ExploreRoundtableCard-questionTitle" data-za-detail-view-id="5800" href="/question/30096305" rel="noopener noreferrer" target="_blank">
#              女生夏季必备单品有哪些？
#             </a>
#             <div class="ExploreRoundtableCard-questionCounts">
#              <span>
#               253
#               <!-- -->
#               个回答
#              </span>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="ExploreRoundtableCard ExploreHomePage-roundtableCard">
#           <div class="ExploreRoundtableCard-headerContainer" style="background-color:#421265">
#            <div class="ExploreRoundtableCard-headerBackgrounds">
#             <div style="background-image:url(https://pic2.zhimg.com/50/v2-91ddcb937a6ebdc85ae67c184a2bd520_hd.jpg);background-position:center">
#             </div>
#             <div style="background:linear-gradient(to right, rgba(66, 18, 101, 1) 0%, rgba(66, 18, 101, 0) 100%">
#             </div>
#             <div style="background:linear-gradient(to right, rgba(66, 18, 101, 0.5) 0%, rgba(66, 18, 101, 0) 100%">
#             </div>
#            </div>
#            <div class="ExploreRoundtableCard-header">
#             <a class="ExploreRoundtableCard-title" data-za-detail-view-id="5799" href="/roundtable/vrshidailailinlema" rel="noreferrer noopener" target="_blank">
#              VR时代来临了吗？
#             </a>
#             <a class="ExploreRoundtableCard-intro" data-za-detail-view-id="5799" href="/roundtable/vrshidailailinlema" rel="noreferrer noopener" target="_blank">
#              虚拟现实是仿真技术的一个重要方向，随着厂商们多年对于产品硬件上的打磨，以及5G时代来临带来的通信便利，人们对VR设备的关注度愈来愈高。到了现在，我们离VR时代究竟还有多远？它又能为我们现实世界带来多大的便利呢？
#             </a>
#             <div class="ExploreRoundtableCard-info">
#              <div class="ExploreRoundtableCard-guests">
#               <img src="https://pic3.zhimg.com/50/v2-dbc851945aea371c641e8d4216ae3c10_hd.jpg"/>
#               <img src="https://pic3.zhimg.com/50/v2-60dc5be1e9f34a68b6d4bb211c649161_hd.jpg"/>
#               <img src="https://pic4.zhimg.com/50/v2-a6a19732e1c1050544d6c9480e3cdaee_hd.jpg"/>
#               <span>
#                4
#                <!-- -->
#                位嘉宾参与
#               </span>
#              </div>
#              <div class="ExploreRoundtableCard-count">
#               <span>
#                80
#                <!-- -->
#                人关注
#               </span>
#              </div>
#             </div>
#            </div>
#            <div class="ExploreRoundtableCard-followButton">
#             <button class="ExploreFollowButton ExploreFollowButton--colored" style="color:rgba(66, 18, 101, 1)">
#              关注圆桌
#             </button>
#            </div>
#           </div>
#           <div class="ExploreRoundtableCard-questionList">
#            <div class="ExploreRoundtableCard-questionItem">
#             <a class="ExploreRoundtableCard-questionTitle" data-za-detail-view-id="5800" href="/question/40479545" rel="noopener noreferrer" target="_blank">
#              VR 是不是伪需求？
#             </a>
#             <div class="ExploreRoundtableCard-questionCounts">
#              <span>
#               530
#               <!-- -->
#               个回答
#              </span>
#             </div>
#            </div>
#            <div class="ExploreRoundtableCard-questionItem">
#             <a class="ExploreRoundtableCard-questionTitle" data-za-detail-view-id="5800" href="/question/39947219" rel="noopener noreferrer" target="_blank">
#              VR 电影目前最大的瓶颈是什么？
#             </a>
#             <div class="ExploreRoundtableCard-questionCounts">
#              <span>
#               127
#               <!-- -->
#               个回答
#              </span>
#             </div>
#            </div>
#            <div class="ExploreRoundtableCard-questionItem">
#             <a class="ExploreRoundtableCard-questionTitle" data-za-detail-view-id="5800" href="/question/35942279" rel="noopener noreferrer" target="_blank">
#              市面上能买到的 VR 设备有哪些值得推荐？
#             </a>
#             <div class="ExploreRoundtableCard-questionCounts">
#              <span>
#               100
#               <!-- -->
#               个回答
#              </span>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="ExploreHomePage-ContentSection-moreButton">
#         <a data-za-detail-view-id="5802" href="/roundtable" rel="noreferrer noopener" target="_blank">
#          查看更多圆桌
#          <svg class="Zi Zi--ArrowRight" fill="currentColor" height="25" viewbox="0 0 24 24" width="25">
#           <path d="M9.218 16.78a.737.737 0 0 0 1.052 0l4.512-4.249a.758.758 0 0 0 0-1.063L10.27 7.22a.737.737 0 0 0-1.052 0 .759.759 0 0 0-.001 1.063L13 12l-3.782 3.716a.758.758 0 0 0 0 1.063z" fill-rule="evenodd">
#           </path>
#          </svg>
#         </a>
#        </div>
#       </div>
#       <div class="ExploreHomePage-ContentSection ExploreHomePage-section" id="collection">
#        <div class="ExploreHomePage-ContentSection-header">
#         <svg class="Zi Zi--Star" fill="currentColor" height="36" viewbox="0 0 24 24" width="36">
#          <path d="M5.515 19.64l.918-5.355-3.89-3.792c-.926-.902-.639-1.784.64-1.97L8.56 7.74l2.404-4.871c.572-1.16 1.5-1.16 2.072 0L15.44 7.74l5.377.782c1.28.186 1.566 1.068.64 1.97l-3.89 3.793.918 5.354c.219 1.274-.532 1.82-1.676 1.218L12 18.33l-4.808 2.528c-1.145.602-1.896.056-1.677-1.218z" fill-rule="evenodd">
#          </path>
#         </svg>
#         <span>
#          热门收藏夹
#         </span>
#        </div>
#        <div class="ExploreHomePage-ContentSection-body">
#         <div class="ExploreHomePage-collections">
#          <div class="ExploreCollectionCard ExploreHomePage-collectionCard">
#           <div class="ExploreCollectionCard-header">
#            <div class="ExploreCollectionCard-info">
#             <a class="ExploreCollectionCard-title" data-za-detail-view-id="5804" data-za-detail-view-name="标题点击" href="/collection/20153420" rel="noopener noreferrer" target="_blank">
#              游戏设计
#             </a>
#             <div class="ExploreCollectionCard-relatedMembers">
#              <div class="ExploreCollectionCard-creator">
#               <span class="UserLink ExploreCollectionCard-creatorAvatar">
#                <div class="Popover">
#                 <div aria-expanded="false" aria-haspopup="true" aria-owns="null-content" id="null-toggle">
#                  <a class="UserLink-link" data-za-detail-view-element_name="User" data-za-detail-view-id="5806" href="//www.zhihu.com/people/plink6" target="_blank">
#                   <img alt="唐梓瑶" class="Avatar UserLink-avatar" height="28" src="https://pic2.zhimg.com/v2-4fc5ae9ae6105d8a17bb2189039fc1ef_is.jpg" srcset="https://pic2.zhimg.com/v2-4fc5ae9ae6105d8a17bb2189039fc1ef_im.jpg 2x" width="28"/>
#                  </a>
#                 </div>
#                </div>
#               </span>
#               <a class="ExploreCollectionCard-creatorName" data-za-detail-view-id="5806" href="/people/plink6" rel="noopener noreferrer" target="_blank">
#                唐梓瑶
#               </a>
#               <span class="ExploreCollectionCard-creatorSuffix">
#                创建
#               </span>
#              </div>
#              <div class="ExploreCollectionCard-followers">
#               798
#               <!-- -->
#               人关注
#              </div>
#             </div>
#            </div>
#            <div class="ExploreCollectionCard-followButton">
#             <button class="ExploreFollowButton">
#              关注收藏夹
#             </button>
#            </div>
#           </div>
#           <div class="ExploreCollectionCard-contentList">
#            <div class="ExploreCollectionCard-contentItem">
#             <a class="ExploreCollectionCard-contentTitle" data-za-detail-view-id="5807" href="https://zhuanlan.zhihu.com/p/150047773" rel="noopener noreferrer" target="_blank">
#              《终结降临》主演访谈：「游戏+电影」，欲罢不能的新奇体验
#             </a>
#             <div class="ExploreCollectionCard-contentExcerpt">
#              篝火营地：
#              <b>
#               —— 本乡奏多VS栗山千明会擦出怎样的火花？
#              </b>
#              <i>
#               本次《Fami 通》编辑采访到的是饰演本作主人公唐木诚的本乡奏多先生以及栗山千明小姐，她饰演的幸村茜与唐木有着神秘而千丝万缕的联系。两位演员都是首次挑战真人电影游戏，那么他们对于本作有着什么样的心声呢？…
#              </i>
#             </div>
#             <div class="ExploreCollectionCard-contentTags">
#              <span class="ExploreCollectionCard-contentTypeTag">
#               文章
#              </span>
#              <span class="ExploreCollectionCard-contentCountTag">
#               8 赞同
#              </span>
#              <span class="ExploreCollectionCard-contentCountTag">
#               0 评论
#              </span>
#             </div>
#            </div>
#            <div class="ExploreCollectionCard-contentItem">
#             <a class="ExploreCollectionCard-contentTitle" data-za-detail-view-id="5807" href="https://zhuanlan.zhihu.com/p/151238164" rel="noopener noreferrer" target="_blank">
#              [教程汇总+持续更新]Unity从入门到入土——收藏这一篇就够了
#             </a>
#             <div class="ExploreCollectionCard-contentExcerpt">
#              知乎用户：在知乎做Unity教程快1年了，从实战到各种教程翻译已经快200多篇文章了（有一部分已经准备好了，尚未发布）。我做教程的理念受
#              <u>
#               <a class="wrap external" href="https://link.zhihu.com/?target=https%3A//catlikecoding.com/jasper-flick/" rel="nofollow noreferrer" target="_blank">
#                Jasper Flick
#               </a>
#              </u>
#              影响，我认为知识应该成体系的去讲解。我的教程基本都是基于这个理念去做的。不管是原创系列还是翻译系列。但即使…
#             </div>
#             <div class="ExploreCollectionCard-contentTags">
#              <span class="ExploreCollectionCard-contentTypeTag">
#               文章
#              </span>
#              <span class="ExploreCollectionCard-contentCountTag">
#               285 赞同
#              </span>
#              <span class="ExploreCollectionCard-contentCountTag">
#               27 评论
#              </span>
#             </div>
#            </div>
#           </div>
#           <a class="ExploreCollectionCard-collectedContentCount" data-za-detail-view-id="5804" data-za-detail-view-name="已收藏点击" href="/collection/20153420" rel="noopener noreferrer" target="_blank">
#            已收藏
#            <!-- -->
#            8,492
#            <!-- -->
#            条内容
#            <svg class="Zi Zi--ArrowRight" fill="currentColor" height="24" viewbox="0 0 24 24" width="24">
#             <path d="M9.218 16.78a.737.737 0 0 0 1.052 0l4.512-4.249a.758.758 0 0 0 0-1.063L10.27 7.22a.737.737 0 0 0-1.052 0 .759.759 0 0 0-.001 1.063L13 12l-3.782 3.716a.758.758 0 0 0 0 1.063z" fill-rule="evenodd">
#             </path>
#            </svg>
#           </a>
#          </div>
#          <div class="ExploreCollectionCard ExploreHomePage-collectionCard">
#           <div class="ExploreCollectionCard-header">
#            <div class="ExploreCollectionCard-info">
#             <a class="ExploreCollectionCard-title" data-za-detail-view-id="5804" data-za-detail-view-name="标题点击" href="/collection/41389806" rel="noopener noreferrer" target="_blank">
#              残编断简
#             </a>
#             <div class="ExploreCollectionCard-relatedMembers">
#              <div class="ExploreCollectionCard-creator">
#               <span class="UserLink ExploreCollectionCard-creatorAvatar">
#                <img alt="知乎用户" class="Avatar UserLink-avatar" height="28" src="https://pic4.zhimg.com/da8e974dc_is.jpg" srcset="https://pic4.zhimg.com/da8e974dc_im.jpg 2x" width="28"/>
#               </span>
#               <a class="ExploreCollectionCard-creatorName" data-za-detail-view-id="5806" href="/people/" rel="noopener noreferrer" target="_blank">
#                知乎用户
#               </a>
#               <span class="ExploreCollectionCard-creatorSuffix">
#                创建
#               </span>
#              </div>
#              <div class="ExploreCollectionCard-followers">
#               1,382
#               <!-- -->
#               人关注
#              </div>
#             </div>
#            </div>
#            <div class="ExploreCollectionCard-followButton">
#             <button class="ExploreFollowButton">
#              关注收藏夹
#             </button>
#            </div>
#           </div>
#           <div class="ExploreCollectionCard-contentList">
#            <div class="ExploreCollectionCard-contentItem">
#             <a class="ExploreCollectionCard-contentTitle" data-za-detail-view-id="5807" href="https://www.zhihu.com/answer/1307110843" rel="noopener noreferrer" target="_blank">
#              当初的人民公社为什么积极性不高？
#             </a>
#             <div class="ExploreCollectionCard-contentExcerpt">
#              春过雪消：首先声明，我摘录这几段资料不是为了宣扬或否定什么，请不带任何偏见来认真阅读、或者至少看完本文。文章不看完就瞎扯的喷子请出门右转找卫生间。一、河北省晋州市有一个号称全国唯一完整地保存下来的人民公社——周家庄人民公社（同时挂周家庄乡的牌子）。…
#             </div>
#             <div class="ExploreCollectionCard-contentTags">
#              <span class="ExploreCollectionCard-contentTypeTag">
#               回答
#              </span>
#              <span class="ExploreCollectionCard-contentCountTag">
#               157 赞同
#              </span>
#              <span class="ExploreCollectionCard-contentCountTag">
#               32 评论
#              </span>
#             </div>
#            </div>
#            <div class="ExploreCollectionCard-contentItem">
#             <a class="ExploreCollectionCard-contentTitle" data-za-detail-view-id="5807" href="https://www.zhihu.com/answer/1292038459" rel="noopener noreferrer" target="_blank">
#              为什么中国要严格控制枪械？
#             </a>
#             <div class="ExploreCollectionCard-contentExcerpt">
#              Euirrx：我出生在云南，大家恐怕不知道什么叫抢收烤烟，这是至少十年前，我们那里年年发生的。烟草支撑了云南绝大部分GDP，官方种植，民间也在种植，利润特高，一亩地种粮食的利润连烟草十分之一都不到。我们县比较穷，县财政发完工资就没什么钱，为了增加收入，政…
#             </div>
#             <div class="ExploreCollectionCard-contentTags">
#              <span class="ExploreCollectionCard-contentTypeTag">
#               回答
#              </span>
#              <span class="ExploreCollectionCard-contentCountTag">
#               3,013 赞同
#              </span>
#              <span class="ExploreCollectionCard-contentCountTag">
#               434 评论
#              </span>
#             </div>
#            </div>
#           </div>
#           <a class="ExploreCollectionCard-collectedContentCount" data-za-detail-view-id="5804" data-za-detail-view-name="已收藏点击" href="/collection/41389806" rel="noopener noreferrer" target="_blank">
#            已收藏
#            <!-- -->
#            1,011
#            <!-- -->
#            条内容
#            <svg class="Zi Zi--ArrowRight" fill="currentColor" height="24" viewbox="0 0 24 24" width="24">
#             <path d="M9.218 16.78a.737.737 0 0 0 1.052 0l4.512-4.249a.758.758 0 0 0 0-1.063L10.27 7.22a.737.737 0 0 0-1.052 0 .759.759 0 0 0-.001 1.063L13 12l-3.782 3.716a.758.758 0 0 0 0 1.063z" fill-rule="evenodd">
#             </path>
#            </svg>
#           </a>
#          </div>
#          <div class="ExploreCollectionCard ExploreHomePage-collectionCard">
#           <div class="ExploreCollectionCard-header">
#            <div class="ExploreCollectionCard-info">
#             <a class="ExploreCollectionCard-title" data-za-detail-view-id="5804" data-za-detail-view-name="标题点击" href="/collection/60058588" rel="noopener noreferrer" target="_blank">
#              经济，政治，社会热点
#             </a>
#             <div class="ExploreCollectionCard-relatedMembers">
#              <div class="ExploreCollectionCard-creator">
#               <span class="UserLink ExploreCollectionCard-creatorAvatar">
#                <div class="Popover">
# ...
#                  </a>
#                 </div>
#                </div>
#               </span>
#               <a class="ExploreCollectionCard-creatorName" data-za-detail-view-id="5806" href="/people/zhangletao" rel="noopener noreferrer" target="_blank">
#                张乐陶
#               </a>
#               <span class="ExploreCollectionCard-creatorSuffix">
#                创建
#               </span>
#              </div>
#              <div class="ExploreCollectionCard-followers">
#               418
#               <!-- -->
#               人关注
#              </div>
#             </div>
#            </div>
#            <div class="ExploreCollectionCard-followButton">
#             <button class="ExploreFollowButton">
#              关注收藏夹
#             </button>
#            </div>
#           </div>
#           <div class="ExploreCollectionCard-contentList">
#            <div class="ExploreCollectionCard-contentItem">
#             <a class="ExploreCollectionCard-contentTitle" data-za-detail-view-id="5807" href="https://www.zhihu.com/answer/1307618478" rel="noopener noreferrer" target="_blank">
#              为何马云退休后，阿里的黑料变多了？
#             </a>
#             <div class="ExploreCollectionCard-contentExcerpt">
#              于彼朝阳：最近我买肉时，突然有一些感想。我国最近二十年是国际上微操玩得好，吃全球经济红利，才掩盖了底层人民没有足够的诉求主动权这一事实。最近为什么大家网上“仇富”的牢骚多了？因为富人本来就不仁啊，存量他们已经死死霸住了。老百姓之所以觉得还有奔头，是…
#             </div>
#             <div class="ExploreCollectionCard-contentTags">
#              <span class="ExploreCollectionCard-contentTypeTag">
#               回答
#              </span>
#              <span class="ExploreCollectionCard-contentCountTag">
#               16,949 赞同
#              </span>
#              <span class="ExploreCollectionCard-contentCountTag">
#               979 评论
#              </span>
#             </div>
#            </div>
#            <div class="ExploreCollectionCard-contentItem">
#             <a class="ExploreCollectionCard-contentTitle" data-za-detail-view-id="5807" href="https://www.zhihu.com/answer/73219657" rel="noopener noreferrer" target="_blank">
#              同样的坑道战，为何志愿军能守住上甘岭，而日军却只落得全军覆没的下场？
#             </a>
#             <div class="ExploreCollectionCard-contentExcerpt">
#              Wei William：首先，
#              <b>
#               你应该订正你的论断，美军并非对志愿军完全束手无策，而是坑道战术极大减少了志愿军的伤亡，让美军强行肃清志愿军坑道的代价难以承受，战争打成了烂仗，而
#              </b>
#              <b>
#               并非杜绝了伤亡
#              </b>
#              。先明确这一点，然后我们才能继续分析原因。 原因有四：
#              <b>
#               1.朝鲜战争是一场有限…
#              </b>
#             </div>
#             <div class="ExploreCollectionCard-contentTags">
#              <span class="ExploreCollectionCard-contentTypeTag">
#               回答
#              </span>
#              <span class="ExploreCollectionCard-contentCountTag">
#               5,298 赞同
#              </span>
#              <span class="ExploreCollectionCard-contentCountTag">
#               328 评论
#              </span>
#             </div>
#            </div>
#           </div>
#           <a class="ExploreCollectionCard-collectedContentCount" data-za-detail-view-id="5804" data-za-detail-view-name="已收藏点击" href="/collection/95922523" rel="noopener noreferrer" target="_blank">
#            已收藏
#            <!-- -->
#            1,465
#            <!-- -->
#            条内容
#            <svg class="Zi Zi--ArrowRight" fill="currentColor" height="24" viewbox="0 0 24 24" width="24">
#             <path d="M9.218 16.78a.737.737 0 0 0 1.052 0l4.512-4.249a.758.758 0 0 0 0-1.063L10.27 7.22a.737.737 0 0 0-1.052 0 .759.759 0 0 0-.001 1.063L13 12l-3.782 3.716a.758.758 0 0 0 0 1.063z" fill-rule="evenodd">
#             </path>
#            </svg>
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="ExploreHomePage-ContentSection-moreButton">
#         <a data-za-detail-view-id="5808" href="/collection/hot" rel="noreferrer noopener" target="_blank">
#          查看更多收藏夹
#          <svg class="Zi Zi--ArrowRight" fill="currentColor" height="25" viewbox="0 0 24 24" width="25">
#           <path d="M9.218 16.78a.737.737 0 0 0 1.052 0l4.512-4.249a.758.758 0 0 0 0-1.063L10.27 7.22a.737.737 0 0 0-1.052 0 .759.759 0 0 0-.001 1.063L13 12l-3.782 3.716a.758.758 0 0 0 0 1.063z" fill-rule="evenodd">
#           </path>
#          </svg>
#         </a>
#        </div>
#       </div>
#       <div class="ExploreHomePage-ContentSection ExploreHomePage-section" id="column">
#        <div class="ExploreHomePage-ContentSection-header">
#         <svg class="Zi Zi--EditCircle" fill="currentColor" height="36" viewbox="0 0 24 24" width="36">
#          <path d="M12 22C6.477 22 2 17.523 2 12S6.477 2 12 2s10 4.477 10 10-4.477 10-10 10zm4.043-15.524a.745.745 0 0 0-1.053.017l-6.857 7.071 2.237 2.17 6.857-7.071a.743.743 0 0 0-.016-1.052l-1.168-1.135zm-9.028 9.476l-.348 1.381 1.37-.39 1.274-.36-1.973-1.916-.323 1.285z" fill-rule="evenodd">
#          </path>
#         </svg>
#         <span>
#          专栏
#         </span>
#        </div>
#        <div class="ExploreHomePage-ContentSection-body">
#         <div class="ExploreHomePage-columns">
#          <div class="ExploreColumnCard ExploreHomePage-columnCard">
#           <a class="ExploreColumnCard-avatar" data-za-detail-view-id="5810" data-za-detail-view-name="专栏头像点击" href="https://zhuanlan.zhihu.com/jyzyx0" rel="noreferrer noopener" target="_blank">
#            <img src="https://pic4.zhimg.com/v2-034d9ac552750046496bc62437feb7cc_xl.jpg"/>
#           </a>
#           <a class="ExploreColumnCard-title" data-za-detail-view-id="5810" data-za-detail-view-name="专栏名称点击" href="https://zhuanlan.zhihu.com/jyzyx0" rel="noreferrer noopener" target="_blank">
#            张尧浠:《玩赚黄金投资交易》
#           </a>
#           <div class="ExploreColumnCard-count">
#            <span>
#             908
#             <!-- -->
#             关注
#            </span>
#            <span>
#             1,982
#             <!-- -->
#             文章
#            </span>
#           </div>
#           <div class="ExploreColumnCard-intro">
#            贵金属，外汇，股市等投资观点分析、技术理论干货普及
#           </div>
#           <button class="ExploreColumnCard-entryButton">
#            进入专栏
#           </button>
#          </div>
#          <div class="ExploreColumnCard ExploreHomePage-columnCard">
#           <a class="ExploreColumnCard-avatar" data-za-detail-view-id="5810" data-za-detail-view-name="专栏头像点击" href="https://zhuanlan.zhihu.com/c_164949981" rel="noreferrer noopener" target="_blank">
#            <img src="https://pic3.zhimg.com/v2-0f95e252d10c9213787fe938123cf1df_xl.jpg"/>
#           </a>
#           <a class="ExploreColumnCard-title" data-za-detail-view-id="5810" data-za-detail-view-name="专栏名称点击" href="https://zhuanlan.zhihu.com/c_164949981" rel="noreferrer noopener" target="_blank">
#            重庆地产视野
#           </a>
#           <div class="ExploreColumnCard-count">
#            <span>
#             5,423
#             <!-- -->
#             关注
#            </span>
#            <span>
#             951
#             <!-- -->
#             文章
#            </span>
#           </div>
#           <div class="ExploreColumnCard-intro">
#            重庆地产置业和投资经验，微信公号：【重庆地产视野】
#           </div>
#           <button class="ExploreColumnCard-entryButton">
#            进入专栏
#           </button>
#          </div>
#          <div class="ExploreColumnCard ExploreHomePage-columnCard">
#           <a class="ExploreColumnCard-avatar" data-za-detail-view-id="5810" data-za-detail-view-name="专栏头像点击" href="https://zhuanlan.zhihu.com/choutim" rel="noreferrer noopener" target="_blank">
#            <img src="https://pic3.zhimg.com/v2-2fae2561cbb15474d9cc4ab1a35ac252_xl.jpg"/>
#           </a>
#           <a class="ExploreColumnCard-title" data-za-detail-view-id="5810" data-za-detail-view-name="专栏名称点击" href="https://zhuanlan.zhihu.com/choutim" rel="noreferrer noopener" target="_blank">
#            抽屉电影
#           </a>
#           <div class="ExploreColumnCard-count">
#            <span>
#             3,256
#             <!-- -->
#             关注
#            </span>
#            <span>
#             1,482
#             <!-- -->
#             文章
#            </span>
#           </div>
#           <div class="ExploreColumnCard-intro">
#            说电影，也说事情
#           </div>
#           <button class="ExploreColumnCard-entryButton">
#            进入专栏
#           </button>
#          </div>
#          <div class="ExploreColumnCard ExploreHomePage-columnCard">
#           <a class="ExploreColumnCard-avatar" data-za-detail-view-id="5810" data-za-detail-view-name="专栏头像点击" href="https://zhuanlan.zhihu.com/liumeiwang" rel="noreferrer noopener" target="_blank">
#            <img src="https://pic4.zhimg.com/v2-f2535f423a868506686185d0fbfc010d_xl.jpg"/>
#           </a>
#           <a class="ExploreColumnCard-title" data-za-detail-view-id="5810" data-za-detail-view-name="专栏名称点击" href="https://zhuanlan.zhihu.com/liumeiwang" rel="noreferrer noopener" target="_blank">
#            美国高中留学
#           </a>
#           <div class="ExploreColumnCard-count">
#            <span>
#             584
#             <!-- -->
#             关注
#            </span>
#            <span>
#             421
#             <!-- -->
#             文章
#            </span>
#           </div>
#           <div class="ExploreColumnCard-intro">
#            专注美国留学行业20年，低分高录！
#           </div>
#           <button class="ExploreColumnCard-entryButton">
#            进入专栏
#           </button>
#          </div>
#         </div>
#        </div>
#        <div class="ExploreHomePage-ContentSection-moreButton">
#         <a data-za-detail-view-id="5811" href="https://zhuanlan.zhihu.com" rel="noreferrer noopener" target="_blank">
#          查看更多专栏
#          <svg class="Zi Zi--ArrowRight" fill="currentColor" height="25" viewbox="0 0 24 24" width="25">
#           <path d="M9.218 16.78a.737.737 0 0 0 1.052 0l4.512-4.249a.758.758 0 0 0 0-1.063L10.27 7.22a.737.737 0 0 0-1.052 0 .759.759 0 0 0-.001 1.063L13 12l-3.782 3.716a.758.758 0 0 0 0 1.063z" fill-rule="evenodd">
#           </path>
#          </svg>
#         </a>
#        </div>
#       </div>
#       <footer class="PageBottomFooter ExploreHomePage-footer">
#        <a href="https://liukanshan.zhihu.com" rel="noopener noreferrer" target="_blank">
#         刘看山
#        </a>
#        <a href="https://www.zhihu.com/question/19581624" rel="noopener noreferrer" target="_blank">
#         知乎指南
#        </a>
#        <a href="https://www.zhihu.com/term/zhihu-terms" rel="noopener noreferrer" target="_blank">
#         知乎协议
#        </a>
#        <a href="https://www.zhihu.com/app" rel="noopener noreferrer" target="_blank">
#         应用
#        </a>
#        <a href="https://app.mokahr.com/apply/zhihu/3819" rel="noopener noreferrer" target="_blank">
#         工作
#        </a>
#        <a href="https://www.zhihu.com/contact" rel="noopener noreferrer" target="_blank">
#         联系我们
#        </a>
#        <span>
#         ©
#         <!-- -->
#         2020
#         <!-- -->
#         知乎
#        </span>
#       </footer>
#      </div>
#     </main>
#     <div data-zop-usertoken="{}">
#     </div>
#    </div>
#   </div>
#   <script async="" nonce="354fce68-c0c2-4af3-92ce-39b00a7fd819" src="https://www.googletagmanager.com/gtag/js?id=UA-149949619-1">
#   </script>
#   <script nonce="354fce68-c0c2-4af3-92ce-39b00a7fd819">
#    function gtag(){dataLayer.push(arguments)}window.dataLayer=window.dataLayer||[],gtag("js",new Date),gtag("config","UA-149949619-1");
#   </script>
#   <script id="js-clientConfig" type="text/json">
#    {"host":"zhihu.com","protocol":"https:","wwwHost":"www.zhihu.com","fetchRoot":{"www":"https:\u002F\u002Fwww.zhihu.com","api":"https:\u002F\u002Fapi.zhihu.com","zhuanlan":"https:\u002F\u002Fzhuanlan.zhihu.com"}}
#   </script>
#   <script id="js-initialData" type="text/json">
#    {"initialState":{"common":{"ask":{}},"loading":{"global":{"count":0},"local":{"explore\u002FgetLatestSpecials\u002F":false,"explore\u002FgetLatestRoundtables\u002F":false,"explore\u002FgetHotCollections\u002F":false,"explore\u002FgetRecommendColumns\u002F":false}},"club":{"tags":{},"admins":{"data":[]},"members":{"data":[]},"explore":{},"profile":{},"checkin":{},"comments":{"paging":{},"loading":{},"ids":{}},"postList":{"paging":{},"loading":{},"ids":{}},"recommend":{"data":[]},"silences":{"data":[]}},"entities":{"users":{},"questions":{},"answers":{},"articles":{},"columns":{},"topics":{},"roundtables":{},"favlists":{},"comments":{},"notifications":{},"ebooks":{},"activities":{},"feeds":{},"pins":{},"promotions":{},"drafts":{},"chats":{},"posts":{},"clubs":{},"clubTags":{}},"currentUser":"","account":{"lockLevel":{},"unlockTicketStatus":false,"unlockTicket":null,"challenge":[],"errorStatus":false,"message":"","isFetching":false,"accountInfo":{},"urlToken":{"loading":false}},"settings":{"socialBind":null,"inboxMsg":null,"notification":{},"email":{},"privacyFlag":null,"blockedUsers":{"isFetching":false,"paging":{"pageNo":1,"pageSize":6},"data":[]},"blockedFollowees":{"isFetching":false,"paging":{"pageNo":1,"pageSize":6},"data":[]},"ignoredTopics":{"isFetching":false,"paging":{"pageNo":1,"pageSize":6},"data":[]},"restrictedTopics":null,"laboratory":{}},"notification":{},"people":{"profileStatus":{},"activitiesByUser":{},"answersByUser":{},"answersSortByVotesByUser":{},"answersIncludedByUser":{},"votedAnswersByUser":{},"thankedAnswersByUser":{},"voteAnswersByUser":{},"thankAnswersByUser":{},"topicAnswersByUser":{},"zvideosByUser":{},"articlesByUser":{},"articlesSortByVotesByUser":{},"articlesIncludedByUser":{},"pinsByUser":{},"questionsByUser":{},"commercialQuestionsByUser":{},"favlistsByUser":{},"followingByUser":{},"followersByUser":{},"mutualsByUser":{},"followingColumnsByUser":{},"followingQuestionsByUser":{},"followingFavlistsByUser":{},"followingTopicsByUser":{},"publicationsByUser":{},"columnsByUser":{},"allFavlistsByUser":{},"brands":null,"creationsByUser":{},"creationsSortByVotesByUser":{},"creationsFeed":{}},"env":{"ab":{"config":{"experiments":[{"expId":"launch-qa_cl_guest-2","expPrefix":"qa_cl_guest","isDynamicallyUpdated":true,"isRuntime":false,"includeTriggerInfo":false},{"expId":"launch-us_foltopic_user-10","expPrefix":"us_foltopic_user","isDynamicallyUpdated":true,"isRuntime":false,"includeTriggerInfo":false},{"expId":"launch-vd_bullet_second-2","expPrefix":"vd_bullet_second","isDynamicallyUpdated":true,"isRuntime":false,"includeTriggerInfo":false},{"expId":"launch-vd_profile_video-11","expPrefix":"vd_profile_video","isDynamicallyUpdated":true,"isRuntime":false,"includeTriggerInfo":false},{"expId":"launch-vd_timeguide-2","expPrefix":"vd_timeguide","isDynamicallyUpdated":true,"isRuntime":false,"includeTriggerInfo":false},{"expId":"launch-vd_video_replay-3","expPrefix":"vd_video_replay","isDynamicallyUpdated":true,"isRuntime":false,"includeTriggerInfo":false},{"expId":"launch-vd_zvideo_link-10","expPrefix":"vd_zvideo_link","isDynamicallyUpdated":true,"isRuntime":false,"includeTriggerInfo":false},{"expId":"vd_serialpage-1","expPrefix":"vd_serialpage","isDynamicallyUpdated":true,"isRuntime":false,"includeTriggerInfo":false},{"expId":"se_topicfeed-3","expPrefix":"se_topicfeed","isDynamicallyUpdated":true,"isRuntime":false,"includeTriggerInfo":false}],"params":[{"id":"gue_profile_video","type":"String","value":"1"},{"id":"li_paid_answer_exp","type":"String","value":"0","chainId":"_all_"},{"id":"web_creator_route","type":"String","value":"1"},{"id":"se_wil_act","type":"String","value":"0","chainId":"_all_"},{"id":"tsp_hotlist_ui","type":"String","value":"1","chainId":"_all_"},{"id":"tsp_ios_cardredesign","type":"String","value":"0","chainId":"_all_"},{"id":"gue_bullet_second","type":"String","value":"1"},{"id":"zr_slot_training","type":"String","value":"1","chainId":"_all_"},{"id":"se_click_v_v","type":"String","value ...
#   </script>
#   <script src="https://static.zhihu.com/heifetz/vendor.90b6c2c841b0448cdc35.js">
#   </script>
#   <script src="https://static.zhihu.com/heifetz/main.app.9e046b12e3f1b3c6ef6c.js">
#   </script>
#   <script src="https://static.zhihu.com/heifetz/main.explore-routes.4a277a48a798b1078791.js">
#   </script>
#  </body>
#  <script async="" src="https://hm.baidu.com/hm.js?98beee57fd2ef70ccdd5ca52b9740c49">
#  </script>
#  <script async="" src="https://zz.bdstatic.com/linksubmit/push.js">
#  </script>
# </html>

# %% [markdown]
# ### 2. 知乎： https://www.zhihu.com/explore

# %%
url = 'https://www.zhihu.com/explore'
r = requests.get(url)
r.encoding = 'utf-8'

print(r.text[0:600])
# Out:
# <html>
# <head><title>400 Bad Request</title></head>
# <body bgcolor="white">
# <center><h1>400 Bad Request</h1></center>
# <hr><center>openresty</center>
# </body>
# </html>

# %% [markdown]
# ### 3. 觀察一下知乎回來的資料好像有點怪怪的，該怎麼解決？

# %%
import requests
url = 'https://www.zhihu.com/explore'

headers = {'content-type': 'application/json', 'user-agent': 'Mozilla/5.0'}

r = requests.get(url,headers=headers)

r.encoding = 'utf-8'
print(r.text[0:600])
# Out:
# <!doctype html>
# <html lang="zh" data-hairline="true" data-theme="light"><head><meta charSet="utf-8"/><title data-react-helmet="true">发现 - 知乎</title><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1"/><meta name="renderer" content="webkit"/><meta name="force-rendering" content="webkit"/><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/><meta name="google-site-verification" content="FTeR0c8arOPKh8c5DYh_9uu98_zJbaWw53J-Sch9MTg"/><meta name="description" property="og:description" content="有问题，上知乎。知乎，可信赖的问答社区，以让每个人高效获得可信赖的解答为使命。知乎凭借认真、专业和友善的社区氛围，结构化、易获得的
